# %% [markdown]
# # Python Basic Assignment
# ## Assignment - 10 [ FSDS NOV 21 ]

# %% [markdown]
# ### 1. How do you distinguish between shutil.copy() and shutil.copytree()?
# **Ans:**
#
# `shutil.copy()` method is used to copy the contents of a file from one file to another file/folder, it primary takes two arguments `src`,`dest`, `src` represents the file to be copied where as destination refers to the file/folder to where the `src` data should be copied, if `dest` is a folder name the `src` with exact name will be copied to the `dest` folder, if its a file then the contents of `src` will be copied to `dest` where `dest` retains it name.
#
# `shutil.copytree()` function is used to copy the entire contents of a folder to other folder. it also takes two arguments `src` & `dest`, it copies all the content recursively and stores it in `dest`. the important catch here is `dest` must not exist prior to this and it will be created during the copy operation. Permissions and times of directories are copied with `shutil.copystat()` and individual files are copied using `shutil.copy2()` by default which can be modified using `copy_function` attribute.

# %% [markdown]
# ### 2. What function is used to rename files??
# **Ans:**
#
# `os.rename()` function is used to rename files or directories using a python program, this function takes two arguments `src` and `dest`, `src` represents the name file/directory which we want to rename, whereas `dest` represents the new name of the file/directory.

# %% [markdown]
# ### 3. What is the difference between the delete functions in the send2trash and shutil modules?
# **Ans:**
#
# Shutil module provides a funciton called as `shutil.rmtree()` which deletes a directory and all its contents. The other functions with similar functionality are `os.remove()` -> removes a file, `os.rmdir()` removes a empty directory. The problem with these functions is once a file is deleted. it will be lost permanently, if a file is deleted accidentally using these methods there is no way we can recover the deleted file
#
# Where as send2trash module provides a function called `send2trash.send2trash()` to delete a file/directory. these methods moves the files/directories to trash folder instead of permanently deleting them. hence if a file/folder is deleted accidentally it can be still recovered from trash folder, if is deleted using the `send2trash.send2trash()` function. `send2trash` is not included with python standard libary like `os` & `shutil` modules. it needs to be installed explicitly using the command `!pip install send2trash`

# %% [markdown]
# ### 4. ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?
# **Ans:**
#
# ZipFile Module provides a method called as `zipfile`. `ZipFile()` to read and write to zipFiles. it takes arugments lile filename and mode etc `zipfile.ZipFile('filename', mode = 'r')`

# %% [markdown]
# ### 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder
#
# **Ans:**

# %%
import os
import shutil

def search_and_copy(source,destination,extensions):
    source = os.path.abspath(source)
    destination = os.path.abspath(destination)
    for foldername, subfolder, filenames in os.walk(source):
        print(f'Folder Name ➞ {foldername}',end='\n\n')
        print(f'Sub Folders ➞ {subfolder}',end='\n\n')
        print(f'Files ➞ {filenames}',end='\n\n')
        for filename in filenames:
            fileName,extension = os.path.splitext(filename)
            if extension in extensions:
                targetFile = foldername+os.path.sep+fileName+extension
                shutil.copy(targetFile, destination)
        print(f'Files copied successfully from {source} to {destination}')
    
extensions = ['.pdf','.jpg','.ipynb']
source = '/Users/miteshwarke/Documents/iNeuron FSDS'
destination = '/Users/miteshwarke/Documents/iNeuron FSDS/test'
search_and_copy(source, destination, extensions)
# Out:
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS
#
# Sub Folders ➞ ['Other Resources', 'ImageScrapper', 'Assignments', 'test', 'Image-Scraping-From-Specific-Site-using-selenium-main', 'Notes', 'iNeuron Python Projects', 'Imp resources']
#
# Files ➞ ['.DS_Store']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources
#
# Sub Folders ➞ ['DataCamp-Data-Analyst-With-Python-master', 'Comprehensive-Data-Science-Notes-main', 'Python-Notebooks-for-Learning-master', 'SQL-main', 'Machine-Learning-Git-Codebook-master']
#
# Files ➞ ['Matplotlib_Jupyter_Notebook.pdf', '099 Important Note about Pattern Printing Programs.mp4', '.DS_Store', 'AWS_Interview_Guide_1660073292.pdf', 'Whole_ML_PDF-1 1 (1).pdf', 'Python Notes.pdf', 'Python Regex Jupyter Notebook.pdf', 'Plotly_Jupyter_Notebook.pdf', 'Python Basics_Jupyter_Notebook.pdf', 'Data Scientist role.pdf', 'SQL Cheatsheet .pdf', 'Numpy_Jupyter_Notebook.pdf', 'Seaborn_Jupyter_Notebook.pdf', 'Section 2.zip', 'Pandas_Jupyter_Notebook.pdf']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master
#
# Sub Folders ➞ ['02_intermediate_python', '15_joining-data-in-sql', '13_streamlined-data-ingestion-with-pandas', '14_introduction-to-relational-databases-in-sql', '16_introduction-to-databases-in-python', '04_merging-dataframes-with-pandas', '05_introduction-to-data-visualization-with-matplotlib', '10_exploratory-data-analysis-in-python', '01_introduction-to-data-science-in-python', '06_introduction-to-data-visualization-with-seaborn', '08_intermediate-importing-data-in-python', '11_analyzing-police-activity-with-pandas', '03_data-manipulation-with-pandas', '12_introduction-to-sql', '07_introduction-to-importing-data-in-python', '09_cleaning-data-in-python']
#
# Files ➞ ['data-analyst-with-python-track.pdf', 'readme.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/02_intermediate_python
#
# Sub Folders ➞ []
#
# Files ➞ ['04_loops.md', '02_dictionaries-and-pandas.md', 'readme.md', '01_matplotlib.md', '05_case-study-hacker-statistics.md', '03_logic-control-flow-and-filtering.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/15_joining-data-in-sql
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['04_subqueries.md', 'readme.md', '03_set_theory_clauses.md', '01_introduction-to-joins.md', '02_outer-joins-and-cross-joins.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/15_joining-data-in-sql/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['countries2.zip', 'diagrams.zip', 'leaders2.zip']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/13_streamlined-data-ingestion-with-pandas
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['readme.md', '03_importing-data-from-databases.md', '01_importing-data-from-flat-files.md', '04_importing-json-data-and-working-with-apis.md', '02_importing-data-from-excel-files.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/13_streamlined-data-ingestion-with-pandas/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['data.db', 'fcc-new-coder-survey.xlsx', 'vt_tax_data_2016.txt']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/14_introduction-to-relational-databases-in-sql
#
# Sub Folders ➞ []
#
# Files ➞ ['02_enforce-data-consistency-with-attribute-constraints.md', '03_uniquely-identify-records-with-key-constraints.md', '04_glue-together-tables-with-foreign-keys.md', 'readme.md', '01_your-first-database.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/16_introduction-to-databases-in-python
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['04_creating-and-manipulating-your-own-databases.md', '02_applying-filtering-ordering-and-grouping-to-queries.md', '03_advanced-sqlalchemy-queries.md', 'readme.md', '01_basics-of-relational-databases.md', '05_putting-it-all-together.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/16_introduction-to-databases-in-python/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['census.csv', 'employees.sqlite', 'census.sqlite']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/04_merging-dataframes-with-pandas
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['03_merging-data.md', '04_case-study-summer-olmpics.md', 'readme.md', '01_preparing-data.md', '02_concatenating-data.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/04_merging-dataframes-with-pandas/datasets
#
# Sub Folders ➞ ['Pittburgh weather data', 'GDP', 'Oil prices', 'Automobile fuel efficiency', 'Baby names', 'S&P 500 Index', 'Exchange rates', 'Summer Olympic medals']
#
# Files ➞ []
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/04_merging-dataframes-with-pandas/datasets/Pittburgh weather data
#
# Sub Folders ➞ []
#
# Files ➞ ['data.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/04_merging-dataframes-with-pandas/datasets/GDP
#
# Sub Folders ➞ []
#
# Files ➞ ['gdp_china.csv', 'gdp_usa.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/04_merging-dataframes-with-pandas/datasets/Oil prices
#
# Sub Folders ➞ []
#
# Files ➞ ['data.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/04_merging-dataframes-with-pandas/datasets/Automobile fuel efficiency
#
# Sub Folders ➞ []
#
# Files ➞ ['data.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/04_merging-dataframes-with-pandas/datasets/Baby names
#
# Sub Folders ➞ []
#
# Files ➞ ['names1881.csv', 'names1981.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/04_merging-dataframes-with-pandas/datasets/S&P 500 Index
#
# Sub Folders ➞ []
#
# Files ➞ ['data.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/04_merging-dataframes-with-pandas/datasets/Exchange rates
#
# Sub Folders ➞ []
#
# Files ➞ ['data.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/04_merging-dataframes-with-pandas/datasets/Summer Olympic medals
#
# Sub Folders ➞ []
#
# Files ➞ ['bronze_top5.csv', 'Gold.csv', 'gold_top5.csv', 'Silver.csv', 'Summer Olympic medalists 1896 to 2008 - ALL MEDALISTS.tsv', 'silver_top5.csv', 'Bronze.csv', 'Summer Olympic medalists 1896 to 2008 - EDITIONS.tsv', 'Summer Olympic medalists 1896 to 2008 - IOC COUNTRY CODES.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/05_introduction-to-data-visualization-with-matplotlib
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['03-quantitative-comparisons-and-statistical-visualizations.md', '02-plotting-timeseries.md', 'readme.md', '01-introduction-to-matplotlib.md', '04-sharing-visualizations-with-others.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/05_introduction-to-data-visualization-with-matplotlib/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['medals_by_country_2016.csv', 'seattle_weather.csv', 'austin_weather.csv', 'summer2016.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/10_exploratory-data-analysis-in-python
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['01_read-clean-and-validate.md', '03_relationships.md', '02_distributions.md', 'readme.md', '04_multivariate-thinking.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/10_exploratory-data-analysis-in-python/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['gss.hdf5', 'brfss.hdf5', 'nsfg.hdf5']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/01_introduction-to-data-science-in-python
#
# Sub Folders ➞ []
#
# Files ➞ ['2_loading-data-in-pandas.md', 'readme.md', '4_different-types-of-plots.md', '1_getting-started-in-python.md', '3_plotting-data-with-matplotlib.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/06_introduction-to-data-visualization-with-seaborn
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['04_customizing-seaborn-plots.md', '03_visualizing-a-categorical-and-a-quantitative-variable.md', '01_introduction-to-seaborn.md', 'readme.md', '02_visualizing-two-quantitative-variables.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/06_introduction-to-data-visualization-with-seaborn/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['mpg.csv', 'young-people-survey-responses.csv', 'student-alcohol-consumption.csv', 'countries-of-the-world.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/08_intermediate-importing-data-in-python
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['02_interacting-with-apis-to-import-data-from-the-web.md', 'readme.md', '03_diving-deep-into-the-twitter-api.md', '01_importing-data-from-the-internet.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/08_intermediate-importing-data-in-python/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['tweets3.txt', 'winequality-red.csv', 'latitude.xls']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/11_analyzing-police-activity-with-pandas
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['04_analyzing-the-effect-of-weather-on-policing.md', 'readme.md', '02_exploring-the-relationship-between-gender-and-policing.md', '01_preparing-the-data-for-analysis.md', '03_visual-exploratory-data-analysis.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/11_analyzing-police-activity-with-pandas/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['police.csv', 'weather.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/03_data-manipulation-with-pandas
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['01_transforming-data.md', 'readme.md', '04_creating-and-visualizing-dataframes.md', '02_aggregating-data.md', '03_slicing-and-indexing.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/03_data-manipulation-with-pandas/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['walmart_sales.pkl', 'homeless_data.pkl', 'avoplotto.pkl']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/12_introduction-to-sql
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['01_selecting-columns.md', '03_aggregate-functions.md', 'readme.md', '04_sorting-and-grouping.md', '02_filtering-rows.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/12_introduction-to-sql/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['films.sql']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/07_introduction-to-importing-data-in-python
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['03_working-with-relational-databases-in-python.md', '01_introduction-and-flat-files.md', 'readme.md', '02_importing-data-from-other-file-types.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/07_introduction-to-importing-data-in-python/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['disarea.dta', 'sales.sas7bdat', 'ja_data2.mat', 'battledeath.xlsx', 'titanic_sub.csv', 'Chinook.sqlite', 'L-L1_LOSC_4_V1-1126259446-32.hdf5', 'mnist_kaggle_some_rows.csv', 'seaslug.txt']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/09_cleaning-data-in-python
#
# Sub Folders ➞ ['datasets']
#
# Files ➞ ['01_common-data-problems.md', '04_record-linkage.md', '03_advanced-data-problems.md', 'readme.md', '02_text-and-categorical-data-problems.md']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/DataCamp-Data-Analyst-With-Python-master/09_cleaning-data-in-python/datasets
#
# Sub Folders ➞ []
#
# Files ➞ ['airlines_final.csv', 'restaurants_L2_dirty.csv', 'banking_dirty.csv', 'ride_sharing_new.csv', 'restaurants_L2.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Comprehensive-Data-Science-Notes-main
#
# Sub Folders ➞ ['Andrew NG', 'iNeuron']
#
# Files ➞ ['o mining-the-social-web-2nd-edition.pdf', 'pandas-cheat-sheet.pdf', 'Tableau-Cheat-Sheet.pdf', 'o Clinton W. Brownley-Foundations for Analytics with Python-O’Reilly Media (2016).pdf', 'Python Pandas Quick Refresher.pdf', 'Git-cheatsheet-EN-white.pdf', 'Data Analysis Expressions - DAX - Reference.pdf', 'ML Engineering.pdf', 'Natural_Language_Processing_with_Python.pdf', 'Transfer Learning - Qiang Yang.pdf', 'Mathematics for Machine Learning.pdf', 'DS Cheatsheet 1.0.pdf', 'Statistics for Business and Economics.pdf', 'An Introduction to Statistical Learning(1).pdf', 'Seaborn_python_cheatsheet.pdf', 'Data Science blogs.pdf', 'Amazon Simple Storage Service.pdf', 'UltimateGuidetoDataScienceInterviews-2.pdf', 'Oracle9_SQL.pdf', 'Hadoop-The.Definitive.Guide_4.edition_a_Tom.White_April-2015-1.pdf', 'PythonForDataScience.pdf', 'Kubernetes_cheat_sheet_r1v1.pdf', 'Scikit-learn-cheat-sheet.pdf', 'Practical Python AI Projects.pdf', 'Statistical inference in data science.pdf', 'Data_Analytics_Book_1638257789.pdf', 'Deep Learning Interview Book.pdf', 'o Hands_On_Machine_Learning_with_Scikit_Learn_and_TensorFlow(DynamicDuniya.com).pdf', '.DS_Store', 'Programming Computer Vision.pdf', 'Getting your first Data Science Job.pdf', 'Bayesian Reasoning and Machine Learning.pdf', 'Feature Engineering.pdf', 'Data Science for Business.pdf', 'Pandas DataFrame.pdf', 'Time Series_Python.pdf', 'Python.pdf', 'Python_Cheatsheet_1630774398.pdf', '365 Data Science Interview Questions.pdf', 'Practical Statistics for Data Scientists.pdf', 'Python Data Analytics_ Data Analysis and Science Using Pandas, matplotlib, and the Python Programming Language ( PDFDrive ) (1).pdf', 'Achieving higher supply chain performance.pdf', 'SQL For Dummies.pdf', 'NLP Questions.pdf', 'Statistics in python.pdf', 'Neural Networks and Deep Learning.pdf', 'Python-cheat-sheet-intermediate.pdf', 'Working_with_Dates_in_Pandas_1618124604.pdf', 'GIT.pdf', 'Combined forecast.pdf', 'Beginning Regular Expressions.pdf', 'Complete ML Notes.pdf', 'Introduction to Machine Learning.pdf', 'Demand Forecasting for Inventory Control ( PDFDrive ).pdf', 'Machine_Learning_in_Action.pdf', 'Rules of ML Engineering.pdf', '101 Data Science Questions.pdf', 'Larry Wasserman_ALL OF Statistics.pdf', 'Element of Statistics Learning.pdf', 'The Execative Guide to AI v2020.pdf', 'Probability for Data Science.pdf', 'Sugiyama, Masashi Statistical Reinforcement Learning Modern Machine Learning Approaches.pdf', 'Time Series Analysis_ Forecasting and Control ( PDFDrive ).pdf', 'ML Questions.pdf', 'SQL.pdf', 'Demand and Supply Integration_ The Key to World-Class Demand Forecasting ( PDFDrive ).pdf', 'JupyterLab-Notebook-Cheatsheet.pdf', '41 Essential Machine Learning Questions.pdf', 'A BeginnerS Guide To R.pdf', 'Data Science Online Resources.pdf', 'Analyzing Data with Power BI and Power Pivot for Excel-2017.pdf', 'o Steven Bird, Ewan Klein, Edward Loper-Natural Language Processing with Python_ Analyzing Text with the Natural Language Toolkit-O_Reilly Media (2009).pdf', 'Storytelling-with-data-cole-nussbaumer-knaflic.pdf', 'Matplotlib_python_cheatsheet.pdf', '164_Data_Science_Interview_Questions_1627104577.pdf', 'Imp Q_A.pdf', 'Intoduction to Statistical Learning.pdf', 'ML  questions .pdf', 'M2-Machine_Learning_By_Ethem_Alpaydin.pdf', 'Microsoft_Press_ebook_Introducing_Power_BI_PDF (1).pdf', 'ML questions_part2.pdf', 'Mastering Machine Learning with scikit-learn.pdf', 'matplotlib cheat sheet.pdf', 'Masato_Hagiwara_Real_World_Natural_Language_Processing_Practical.pdf', 'An Introduction to Statistical Learning.pdf', 'Deep Learning-Ian Goodfellow.pdf', 'Machine Learning with TensorFlow.pdf', 'o Learning_SQL_Second_Edition.pdf', 'Algorithms for Data Science ( PDFDrive ).pdf', 'Data Scientist Interview Questions.pdf', 'Data Science Fundamentals for Python and MongoDB.pdf', 'Data-Exploration-in-Python.pdf', 'Introduction to Time Series Analysis and Forecasting ( PDFDrive ).pdf', 'Data Science Interview Questions.pdf', 'VS ...
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Comprehensive-Data-Science-Notes-main/Andrew NG
#
# Sub Folders ➞ []
#
# Files ➞ ['Machine Learning.pdf', 'Deep learning.pdf']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Comprehensive-Data-Science-Notes-main/iNeuron
#
# Sub Folders ➞ []
#
# Files ➞ ['day 18.pdf', 'day 24.pdf', 'day 30.pdf', 'day 25.pdf', 'day 19.pdf', 'day 27.pdf', 'day 9.pdf', 'day 26.pdf', 'day 8.pdf', 'day 22.pdf', 'day 23.pdf', 'day 21.pdf', 'day 20.pdf', 'a.txt', 'day 3.pdf', 'day 11.pdf', 'day 10.pdf', 'day 2.pdf', 'day 12.pdf', 'day 13.pdf', 'day 1.pdf', 'day 17.pdf', 'day 5.pdf', 'day 4.pdf', 'day 16.pdf', 'day 14.pdf', 'day 6.pdf', 'day 28.pdf', 'day 7.pdf', 'day 29.pdf', 'day 15.pdf']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Python-Notebooks-for-Learning-master
#
# Sub Folders ➞ ['Modular Coding_Perceptron', 'Perceptron Implementation', 'Transfer Learning Example']
#
# Files ➞ ['Matplotlib_Jupyter_Notebook.pdf', 'Dropout_Regularization.ipynb', 'Activation_Functions_Comprehensive.ipynb', 'ANN with Callbacks_Tensorboard,_Early_Stopping,_Model_Checkpointing.ipynb', 'Activation Functions _Theory.pdf', 'Loss_Functions_Theory.ipynb', 'Plotly_Jupyter_Notebook.pdf', 'Python Basics_Jupyter_Notebook.pdf', 'ANN Implementation using Keras.ipynb', 'Readme.md', 'Analyzing Big Data using Chunk Param Pandas_Jupyter Notebook.pdf', 'Analyzing Big Data using Dask_Jupyter Notebook.pdf', 'Numpy_Jupyter_Notebook.pdf', 'Seaborn_Jupyter_Notebook.pdf', 'Regularization.ipynb', 'ANN_Implementation_using_Batch_Normalization.ipynb', 'OOP Python.pdf', 'Pandas_Jupyter_Notebook.pdf', 'Helper Function for Activation Functions.ipynb', 'Analyzing Big Data using Pyspark_Jupyter Notebook.pdf']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Python-Notebooks-for-Learning-master/Modular Coding_Perceptron
#
# Sub Folders ➞ ['utils', 'model', 'Research_notebooks', 'plots']
#
# Files ➞ ['requirements.txt', 'or.py', 'README.md', '.gitignore', 'and.py']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Python-Notebooks-for-Learning-master/Modular Coding_Perceptron/utils
#
# Sub Folders ➞ []
#
# Files ➞ ['__init__.py', 'model.py', 'all_utils.py']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Python-Notebooks-for-Learning-master/Modular Coding_Perceptron/model
#
# Sub Folders ➞ []
#
# Files ➞ ['and.model', 'or.model']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Python-Notebooks-for-Learning-master/Modular Coding_Perceptron/Research_notebooks
#
# Sub Folders ➞ []
#
# Files ➞ ['Perceptron.ipynb']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Python-Notebooks-for-Learning-master/Modular Coding_Perceptron/plots
#
# Sub Folders ➞ []
#
# Files ➞ ['and.png', 'or.png']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Python-Notebooks-for-Learning-master/Perceptron Implementation
#
# Sub Folders ➞ ['model', 'plots', 'model_or']
#
# Files ➞ ['LICENSE', 'requirements.txt', 'README.md', '.gitignore', 'Perceptron.ipynb', 'Perceptron_.png']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Python-Notebooks-for-Learning-master/Perceptron Implementation/model
#
# Sub Folders ➞ []
#
# Files ➞ ['and.model']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Python-Notebooks-for-Learning-master/Perceptron Implementation/plots
#
# Sub Folders ➞ []
#
# Files ➞ ['and.png', 'xor.png', 'or.png']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Python-Notebooks-for-Learning-master/Perceptron Implementation/model_or
#
# Sub Folders ➞ []
#
# Files ➞ ['or.model']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Python-Notebooks-for-Learning-master/Transfer Learning Example
#
# Sub Folders ➞ []
#
# Files ➞ []
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/SQL-main
#
# Sub Folders ➞ []
#
# Files ➞ ['SQL Basics.pdf', 'SQL For Data Science.pdf', 'SQL Commands Handwritten.pdf', 'SQL document Part-2.pdf', 'SQL eBook.pdf', 'SQL Interview Questions.pdf', 'Sql Short Notes Part 3.pdf', 'SQL Leetcode Solutions.pdf', 'SQL Learning Resources.docx', 'SQL_Interview_Questions.pdf', 'README.md', 'SQL Questions.pdf', 'Learning SQL.pdf', 'SQL questions for interview.pdf', 'SQL Optimization .pdf', 'SQL with Python (3).pdf', 'SQL (2).pdf', 'DSI Guide - 10 Common SQL Theory Questions.pdf', 'Sql Notes Part 1 & Part 2 marged.pdf', 'SQL Complete Notes.pdf', 'Study Guide Data Retrieval with sql.pdf', 'Roadmap for SQL_Data Science.pptx', 'SQL Order of Execution .pdf', 'SQL Basics-1.pdf', 'SQL Interview Questions & Answers.pdf', 'SQL Tutorial Notes.pdf', 'SQL- from Basics to Intermediate.pdf', 'SQL Short Notes.pdf', 'SQL Interview Questions & Answers .pdf']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Machine-Learning-Git-Codebook-master
#
# Sub Folders ➞ ['Data Wrangling', 'Data']
#
# Files ➞ ['LR Example.ipynb', '1. NumPy.ipynb', 'Altimetrik - 1.ipynb', '4. Linear Models for Classification & Regression.ipynb', 'Day 1.ipynb', 'Project - Wardrobe Identification.ipynb', 'Project - Customer Churn Prediction.ipynb', 'flask_ml_api.py', 'Cancer Prediction.ipynb', '15. Dealing with Imbalanced Classes.ipynb', '11. Nearest Neighbors.ipynb', 'Case Study using Pipeline & Column Transformer.ipynb', 'Grid Search.ipynb', 'Case Study - Balancing Class.ipynb', 'Case Study - Income Prediction.ipynb', '10. Feature Selection Techniques.ipynb', 'MlModel.py', 'Case Study Clothe Identification.ipynb', 'Project - Reducing colors in image.ipynb', '6. Decision Tree.ipynb', 'Case Study Handwriting Detection.ipynb', 'Project - Recommandation Engine.ipynb', 'Project using Feature Selection.ipynb', '3. Plotting.ipynb', 'mymlproj.zip', 'Comparing Regression.ipynb', 'allstate_train.csv.zip', 'Case Study Churn Prediction.ipynb', '9. Model Selection & Evaluation.ipynb', 'Project - Income Prediction.ipynb', 'Case Study 2 - Review Sentiment Classification.ipynb', 'README.md', 'Project - Face Generation.ipynb', 'Case  Study - IMDB dataset.ipynb', '7. Naive Bayes.ipynb', 'Case Study - Fraud Detection.ipynb', '5. PreProcessing.ipynb', '13. Anomaly Detection.ipynb', 'Case Study - Clustering, Outliers.ipynb', 'Case Study - Face Detection.ipynb', '2. Pandas for Machine Learning.ipynb', 'Online Learning.ipynb', 'Case Study 1 - Employee Attrition Prediction.ipynb', 'Mallicious Network Data Prediction.ipynb', '16. Ensemble Methods.ipynb', '14. Support Vector Machines.ipynb', 'Project - Predicting Employee Exit.ipynb', '8. Composite Estimators using Pipelines & FeatureUnions.ipynb', '1. Introduction to Numpy.ipynb', 'Case Study - HealthCare Data Analysis.ipynb', '17. Association Rules.ipynb', 'Case Study Insurance Amount Prediction.ipynb', 'Project Neighbors & Clustering.ipynb', 'Case Study - Image Compression.ipynb', 'Sony - Pandas & Basic Visualization.ipynb', 'Naive Bayes, Pipelining, GridSearh, ColumnTransformer.ipynb', 'Column Transformer Example.ipynb', 'Case Study - Titanic Shipwrek prediction.ipynb', 'Case Study - Visa Status Prediction.ipynb', '12. Clustering Techniques.ipynb', 'Case Study - Feature Selection on Store Data.ipynb', 'Project - Finding Similar Houses.ipynb', 'Sony - NumPy.ipynb', 'Case Study - House Pricing.ipynb', 'Day1-2.ipynb']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Machine-Learning-Git-Codebook-master/Data Wrangling
#
# Sub Folders ➞ ['images', '.ipynb_checkpoints']
#
# Files ➞ ['1-2. Pandas for Data Wrangling - Objective & Introduction.ipynb', '11. Pandas for Computation.ipynb', '8. Pandas for Data Wrangling - Working with text data.ipynb', '12. Data Transformation using Map, Apply & GroupBy.ipynb', '6. Pandas for Data Wrangling - Merge, Join & Concatenate.ipynb', '4. Pandas for Data Wrangling - Indexing & Selecting Data.ipynb', '5. Pandas for Data Wrangling - Working on TimeSeries Data.ipynb', '3. Pandas for Data Wrangling - Loading Data to DataFrames.ipynb', '10. Styling Pandas Tables.ipynb', '9. Missing Data Handling.ipynb', '7. Pandas for Data Wrangling - Shaping &  Structuring.ipynb']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Machine-Learning-Git-Codebook-master/Data Wrangling/images
#
# Sub Folders ➞ []
#
# Files ➞ ['IO.png', 'sqlite3.png']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Machine-Learning-Git-Codebook-master/Data Wrangling/.ipynb_checkpoints
#
# Sub Folders ➞ []
#
# Files ➞ ['1-2. Pandas for Data Wrangling - Objective & Introduction-checkpoint.ipynb', '6. Pandas for Data Wrangling - Merge, Join & Concatenate-checkpoint.ipynb', '4. Pandas for Data Wrangling - Indexing & Selecting Data-checkpoint.ipynb', '5. Pandas for Data Wrangling - Working on TimeSeries Data-checkpoint.ipynb', '7. Pandas for Data Wrangling - Shaping &  Structuring-checkpoint.ipynb', '3. Pandas for Data Wrangling - Loading Data to DataFrames-checkpoint.ipynb']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Other Resources/Machine-Learning-Git-Codebook-master/Data
#
# Sub Folders ➞ []
#
# Files ➞ ['movies.xml', 'horse.png', 'time_series_covid19_confirmed_global.csv', 'sales-funnel.xlsx', 'payments-data.csv', 'SalesTrainingDataset.csv', 'HR_comma_sep.csv.txt', 'Sample - Superstore.xls', 'horror-test.csv', 'iris', 'books.xml', 'epilepsy.data', 'kids.jpg', 'Shopping_Revenue.csv', 'HealthCareData-1.xlsx', 'movie.json.txt', 'time_series_covid19_deaths_global (1).csv', 'time_series_covid19_recovered_global.csv', 'j.json', 'bank-full.csv', 'Online Retail.xlsx', 'raw_nyc_phil.json', 'student.xml', 'default of credit card clients.xls', 'adult.data.txt', 'cat.jpg', 'tennis-time.csv.txt', 'HealthcareData-2.xlsx', 'cs-training.csv', 'house.model', 'international-airline-passengers.csv', 'PercentagePeopleBelowPovertyLevel.csv', 'sales-data.csv', 'porcupine.jpg', 'horror-train.csv', 'titanic-train.csv.txt', 'MedianHouseholdIncome2015.csv', 'churn.csv.txt', 'sales-of-shampoo-over-a-three-ye.csv', 'tennis.csv.txt', 'gapminder-FiveYearData.csv', 'PoliceKillingsUS.csv', 'ShareRaceByCity.csv', 'winequality-white.csv', 'PercentOver25CompletedHighSchool.csv', 'store.csv', 'house_rental_data.csv.txt']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/ImageScrapper
#
# Sub Folders ➞ ['images', '.idea']
#
# Files ➞ ['scraper.py', '.DS_Store', 'requirements.txt', 'chromedriver.exe', 'chromedriver']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/ImageScrapper/images
#
# Sub Folders ➞ ['cat', 'trees', 'dog', 'narendra_modi']
#
# Files ➞ ['.DS_Store']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/ImageScrapper/images/cat
#
# Sub Folders ➞ []
#
# Files ➞ []
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/ImageScrapper/images/trees
#
# Sub Folders ➞ []
#
# Files ➞ ['jpg_9.jpg', 'jpg_8.jpg', 'jpg_6.jpg', 'jpg_7.jpg', 'jpg_5.jpg', 'jpg_4.jpg', 'jpg_0.jpg', 'jpg_1.jpg', 'jpg_3.jpg', 'jpg_2.jpg']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/ImageScrapper/images/dog
#
# Sub Folders ➞ []
#
# Files ➞ ['jpg_9.jpg', 'jpg_8.jpg', 'jpg_6.jpg', 'jpg_7.jpg', 'jpg_5.jpg', 'jpg_4.jpg', 'jpg_0.jpg', 'jpg_1.jpg', 'jpg_3.jpg', 'jpg_2.jpg']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/ImageScrapper/images/narendra_modi
#
# Sub Folders ➞ []
#
# Files ➞ []
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/ImageScrapper/.idea
#
# Sub Folders ➞ ['inspectionProfiles']
#
# Files ➞ ['ImageScrapper.iml', '.gitignore', 'workspace.xml', 'modules.xml', 'misc.xml']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/ImageScrapper/.idea/inspectionProfiles
#
# Sub Folders ➞ []
#
# Files ➞ ['profiles_settings.xml']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments
#
# Sub Folders ➞ ['9] NLP Assignment', '10] DL And CV Practical Practical Assignment', '11] Assignment TABLEAU', '3] Python Programming Basic Assignment', '15] Assignment Excel', '5] Machine Learning Assignment ', '14] Assignment SQL', '16] Assignment Statistics', '13] Assignment Power BI', '6] Machine Learning Practical Assignment', '4] Python Advance Programming Assignment', '2] Python Advance Assignment ', 'Assignment Solutions', '12] Tableau Projects', '1] Python Basic Assignment ', '7] Deep Learning Assignment', '8] Computer Vision Assignment', '17] DSA Lectures']
#
# Files ➞ ['.DS_Store']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/9] NLP Assignment
#
# Sub Folders ➞ []
#
# Files ➞ ['Assignment_5.docx', 'Assignment_4.docx', 'Assignment_3.docx', 'Assignment_2.docx', 'Assignment_1.docx', 'Assignment_7.docx', 'Assignment_6.docx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/10] DL And CV Practical Practical Assignment
#
# Sub Folders ➞ []
#
# Files ➞ ['Practical Assignment2.docx', 'Practical Assignment10.docx', 'Practical Assignment11.docx', 'Practical Assignment3.docx', 'Practical Assignment20.docx', 'Practical Assignment8.docx', 'Practical Assignment4.docx', 'Practical Assignment16.docx', 'Practical Assignment17.docx', 'Practical Assignment5.docx', 'Practical Assignment9.docx', 'Practical Assignment21.docx', 'Practical Assignment18.docx', 'Practical Assignment22.docx', 'Practical Assignment14.docx', 'Practical Assignment6.docx', 'Practical Assignment7.docx', 'Practical Assignment15.docx', 'Practical Assignment23.docx', 'Practical Assignment19.docx', 'Practical Assignment12.docx', 'Practical Assignment0.docx', 'Practical Assignment24.docx', 'Practical Assignment1.docx', 'Practical Assignment13.docx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU
#
# Sub Folders ➞ ['Assignment-23', 'Assignment-9', 'Assignment-24', 'Assignment-7', 'Assignment-12', 'Assignment-15', 'Assignment-14', 'Assignment-1', 'Assignment-6', 'Assignment-13', 'Assignment-25', 'Assignment-22', 'Assignment-8', 'Assignment-30', 'Assignment-27', 'Assignment-18', 'Assignment-20', 'Assignment-16', 'Assignment-3', 'Assignment-29', 'Assignment-4', 'Assignment-5', 'Assignment-10', 'Assignment-2', 'Assignment-28', 'Assignment-21', 'Assignment-26', 'Assignment-19']
#
# Files ➞ ['.DS_Store']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-23
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Superstore_USA.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-9
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'DataNation.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-24
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Superstore_USA.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-7
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'FDI Case Study.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-12
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Superstore_USA.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-15
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Superstore_USA.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-14
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Superstore_USA.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-1
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Inside_Sales.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-6
#
# Sub Folders ➞ []
#
# Files ➞ ['Supply Chain Master.csv', 'Assignment-6.pdf']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-13
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Superstore_USA.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-25
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Store_Data.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-22
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'MotoCad.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-8
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Superstore_USA.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-30
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Store_Data.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-27
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Store_Data.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-18
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'CarMakers.csv']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-20
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Superstore_USA.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-16
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Superstore_USA.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-3
#
# Sub Folders ➞ []
#
# Files ➞ ['Problem Statement.pdf', 'Superstore_Canada.xls']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-29
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Store_Data.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-4
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'GlobleData.xlsx', 'DataNation.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-5
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Data.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-10
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'DataNation.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-2
#
# Sub Folders ➞ []
#
# Files ➞ ['Problem Statement.pdf', 'Superstore_Canada.xls']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-28
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Store_Data.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-21
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'DataNation.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/11] Assignment TABLEAU/Assignment-26
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Store_Data.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# ...
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/1] Python Basic Assignment /[amanovishnu] Python Basic Assignment/.ipynb_checkpoints
#
# Sub Folders ➞ []
#
# Files ➞ ['03.Assignment_03-checkpoint.ipynb', '02.Assignment_02-checkpoint.ipynb', '01.Assignment_01-checkpoint.ipynb', '10.Assignment_10-checkpoint.ipynb', '04.Assignment_04-checkpoint.ipynb']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/1] Python Basic Assignment /[Gaurav Ratan] Basic_Programming
#
# Sub Folders ➞ []
#
# Files ➞ ['Basic_Programming_Assignment_12.ipynb', 'Basic_Programming_Assignment_10.ipynb', 'Basic_Programming_Assignment_09.ipynb', 'Basic_Programming_Assignment_14.ipynb', 'Basic_Programming_Assignment_16.ipynb', 'Basic_Programming_Assignment_11.ipynb', 'Basic_Programming_Assignment_08.ipynb', 'Basic_Programming_Assignment_13.ipynb', 'Basic_Programming_Assignment_17.ipynb', 'Basic_Programming_Assignment_15.ipynb', 'Basic_Programming_Assignment_19.ipynb', 'Basic_Programming_Assignment_24.ipynb', 'Basic_Programming_Assignment_02.ipynb', 'Basic_Programming_Assignment_22.ipynb', 'Basic_Programming_Assignment_06.ipynb', 'Basic_Programming_Assignment_04.ipynb', 'Basic_Programming_Assignment_20.ipynb', 'Basic_Programming_Assignment_03.ipynb', 'Basic_Programming_Assignment_25.ipynb', 'Basic_Programming_Assignment_18.ipynb', 'Basic_Programming_Assignment_01.ipynb', 'Basic_Programming_Assignment_05.ipynb', 'Basic_Programming_Assignment_21.ipynb', 'Basic_Programming_Assignment_23.ipynb', 'Basic_Programming_Assignment_07.ipynb']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/1] Python Basic Assignment /[Shivaae] Ineuron-Full-Stack-Data-Science-Assignments-main 4
#
# Sub Folders ➞ ['.ipynb_checkpoints']
#
# Files ➞ ['Python Basic Assignment 3.ipynb', 'Python Basic 4.ipynb', 'Python Basic Prog 9.ipynb', 'Python Basic Assignment 1.ipynb', 'Python BAsic 17.ipynb', 'Python Basic Assignment 7.ipynb', 'Python Basic 15.ipynb', 'Python Basic Prog 8.ipynb', 'Python Basic Assignment 2.ipynb', 'zoo.py', 'Python Basic 14.ipynb', 'Python Basic 16.ipynb', 'Python Basic Assignment 13.ipynb', 'README.md', 'Python Basic Prog 10.ipynb', 'Python Basic Assignment 8.ipynb', 'Python Basic 18.ipynb', 'Python Basic 25.ipynb', 'Python Basic Assignment 11.ipynb', 'Python Basics 5.ipynb', 'Python Basic 21.ipynb', 'Python Basic 23.ipynb', 'Python Basic 24.ipynb', 'Python Basic 19.ipynb', 'Python Basic Assignment 10.ipynb', '_PythonBasicProgramming 7.ipynb', 'Python Basics 6.ipynb', 'Python Basic Assignment 12.ipynb', 'Python Basic 22.ipynb', 'Python BAsic 20.ipynb', 'abc.py']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/1] Python Basic Assignment /[Shivaae] Ineuron-Full-Stack-Data-Science-Assignments-main 4/.ipynb_checkpoints
#
# Sub Folders ➞ []
#
# Files ➞ ['Python Basic Assignment 1-checkpoint.ipynb', 'Python Basic 4-checkpoint.ipynb', 'Python Basics 5-checkpoint.ipynb', 'Python Basic Assignment 2-checkpoint.ipynb', 'Python Basic Assignment 3-checkpoint.ipynb']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/1] Python Basic Assignment /[Ashishkumar-hub] Ineuron-Python-Basic-Assignments-main
#
# Sub Folders ➞ ['.ipynb_checkpoints']
#
# Files ➞ ['Ineuron_Python_Assignment13.ipynb', 'Ineuron_Python_Assignment08.ipynb', 'Ineuron_Python_Assignment11.ipynb', 'Ineuron_Python_Assignment15.ipynb', 'Ineuron_Python_Assignment17.ipynb', 'Ineuron_Python_Assignment09.ipynb', 'Ineuron_Python_Assignment10.ipynb', 'Ineuron_Python_Assignment12.ipynb', 'zoo.py', 'Ineuron_Python_Assignment16.ipynb', 'Ineuron_Python_Assignment14.ipynb', 'README.md', 'Ineuron_Python_Assignment01.ipynb', 'Ineuron_Python_Assignment25.ipynb', 'Ineuron_Python_Assignment18.ipynb', 'Ineuron_Python_Assignment03.ipynb', 'Ineuron_Python_Assignment07.ipynb', 'Ineuron_Python_Assignment23.ipynb', 'Ineuron_Python_Assignment21.ipynb', 'Ineuron_Python_Assignment05.ipynb', 'Ineuron_Python_Assignment02.ipynb', 'Ineuron_Python_Assignment19.ipynb', 'Ineuron_Python_Assignment24.ipynb', 'Ineuron_Python_Assignment20.ipynb', 'Ineuron_Python_Assignment04.ipynb', 'Ineuron_Python_Assignment06.ipynb', 'Ineuron_Python_Assignment22.ipynb']
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/1] Python Basic Assignment /[Ashishkumar-hub] Ineuron-Python-Basic-Assignments-main/.ipynb_checkpoints
#
# Sub Folders ➞ []
#
# Files ➞ ['Ineuron_Python_Assignment10-checkpoint.ipynb', 'Ineuron_Python_Assignment04-checkpoint.ipynb', 'Ineuron_Python_Assignment01-checkpoint.ipynb', 'Ineuron_Python_Assignment05-checkpoint.ipynb', 'Ineuron_Python_Assignment09-checkpoint.ipynb', 'Ineuron_Python_Assignment02-checkpoint.ipynb', 'Ineuron_Python_Assignment06-checkpoint.ipynb', 'Ineuron_Python_Assignment03-checkpoint.ipynb']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/1] Python Basic Assignment /[kiranbandgar] Python Assignment
#
# Sub Folders ➞ []
#
# Files ➞ ['Python Assignment No 17.ipynb', 'Python Assignment No 6.docx', 'Python Assignment No 11.docx', 'Python Assignment No 10.docx', 'Python Assignment No 7.docx', 'Python Assignment No 13.ipynb', 'Python Assignment No 14.ipynb', 'Python Assignment No 16.ipynb', 'Python Assignment No 1.docx', 'Python Assignment No 21.ipynb', 'Python Assignment No 2.docx', 'Python Assignment No 23.ipynb', 'Python Assignment No 25.ipynb', 'Python Assignment No 3.docx', 'Python Assignment No 18.ipynb', 'Python Assignment No 22.ipynb', 'Python Assignment No 8.docx', 'Python Assignment No 4.docx', 'Python Assignment No 20.ipynb', 'Python Assignment No 19.ipynb', 'Python Assignment No 5.docx', 'Python Assignment No 24.ipynb', 'Python Assignment No 12.docx', 'Python Assignment No 9.docx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/1] Python Basic Assignment /[HariSankarNayak] Python Basic Assignment
#
# Sub Folders ➞ ['__pycache__', '.ipynb_checkpoints']
#
# Files ➞ ['017.Assignment_17.ipynb', '015.Assignment_15.ipynb', '006.Assignment_6.ipynb', '013.Assignment_13.ipynb', '011.Assignment_11.ipynb', '003.Assignment_3.ipynb', '010.Assignment_10.ipynb', '012.Assignment_12.ipynb', '014.Assignment_14.ipynb', 'zoo.py', '016.Assignment_16.ipynb', '005.Assignment_5.ipynb', '009.Assignment_9.ipynb', '019.Assignment_19.ipynb', '002.Assignment_2.ipynb', '007.Assignment_7.ipynb', '008.Assignment_8.ipynb', '004.Assignment_4.ipynb', '018.Assignment_18.ipynb', '001.Assignment_1.ipynb']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/1] Python Basic Assignment /[HariSankarNayak] Python Basic Assignment/__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['zoo.cpython-310.pyc']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/1] Python Basic Assignment /[HariSankarNayak] Python Basic Assignment/.ipynb_checkpoints
#
# Sub Folders ➞ []
#
# Files ➞ ['006.Assignment_6-checkpoint.ipynb', '007.Assignment_7-checkpoint.ipynb', '008.Assignment_8-checkpoint.ipynb', '004.Assignment_4-checkpoint.ipynb', '009.Assignment_9-checkpoint.ipynb', '005.Assignment_5-checkpoint.ipynb', '001.Assignment_1-checkpoint.ipynb', '003.Assignment_3-checkpoint.ipynb', '002.Assignment_2-checkpoint.ipynb', '010.Assignment_10-checkpoint.ipynb']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/7] Deep Learning Assignment
#
# Sub Folders ➞ []
#
# Files ➞ ['Assignment_5.docx', 'Assignment_9.docx', 'Assignment_12.docx', 'Assignment_13.docx', 'Assignment_8.docx', 'Assignment_4.docx', 'Assignment_14.docx', 'Assignment_3.docx', 'Assignment_2.docx', 'Assignment_15.docx', 'Assignment_16.docx', 'Assignment_1.docx', 'Assignment_7.docx', 'Assignment_10.docx', 'Assignment_11.docx', 'Assignment_6.docx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/8] Computer Vision Assignment
#
# Sub Folders ➞ []
#
# Files ➞ ['Assignment_5.docx', 'Assignment_9.docx', 'Assignment_12.docx', 'Assignment_8.docx', 'Assignment_4.docx', 'Assignment_3.docx', 'Assignment_2.docx', 'Assignment_1.docx', 'Assignment_7.docx', 'Assignment_10.docx', 'Assignment_11.docx', 'Assignment_6.docx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/17] DSA Lectures
#
# Sub Folders ➞ ['Assignment-11', 'Assignment-17']
#
# Files ➞ ['.DS_Store']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/17] DSA Lectures/Assignment-11
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'GlobleData.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/Assignments/17] DSA Lectures/Assignment-17
#
# Sub Folders ➞ []
#
# Files ➞ ['Details.pdf', 'Superstore_USA.xlsx']
#
# Files copied successfully from /Users/miteshwarke/Documents/iNeuron FSDS to /Users/miteshwarke/Documents/iNeuron FSDS/test
# Folder Name ➞ /Users/miteshwarke/Documents/iNeuron FSDS/test
#
# Sub Folders ➞ []
#
# Files ➞ ['Essiesltd.pdf', 'Programming Assignment_25.ipynb', 'Python Basic Assignment 06-checkpoint.ipynb', 'Student Spend Analysis.pdf', 'o mining-the-social-web-2nd-edition.pdf', 'Python Assignment No 17.ipynb', 'LR Example.ipynb', 'pandas-cheat-sheet.pdf', 'Ineuron_Python_Basic_Programming_Assignment15.ipynb', '13.Programming Assignment_13.ipynb', '017.Assignment_17.ipynb', 'SQL Basics.pdf', 'Ineuron_Python_Assignment13.ipynb', 'Python Basic Assignment 3.ipynb', 'day 18.pdf', 'day 24.pdf', 'day 30.pdf', 'Advance_Assignment_25.ipynb', '5. Pandas and Numpy.ipynb', 'Assignment - 14.ipynb', 'Programming Assignment-11.ipynb', 'Advance_Assignment_18.ipynb', 'Tableau-Cheat-Sheet.pdf', '001.Programming_assignment1.ipynb', 'python_basic_Assignment_1-checkpoint.ipynb', 'o Clinton W. Brownley-Foundations for Analytics with Python-O’Reilly Media (2016).pdf', 'Python_Basics_Assignment_11.ipynb', 'Ineuron_Python_Advance_Assignment02.ipynb', 'Programming Assignment_18.ipynb', 'EDA.ipynb', 'Assignment_2.ipynb', 'Python Basic Assignment 01.ipynb', '6. Numpy.ipynb', 'Python Pandas Quick Refresher.pdf', 'Advance Programming Assignment 6.ipynb', 'Assignment_13.ipynb', '015.Assignment_15.ipynb', '1. Flask and API.ipynb', '1. NumPy.ipynb', 'Git-cheatsheet-EN-white.pdf', 'Python Basic Assignment 25.ipynb', 'Altimetrik - 1.ipynb', 'ML_Assignment_08.ipynb', '9. PCA.ipynb', 'Python Session 2.ipynb', 'Ineuron_Python_Advanced_Programming16.ipynb', 'Data Analysis Expressions - DAX - Reference.pdf', 'Python Basic Assignment - 13.ipynb', 'Python_Basics_Assignment_9.ipynb', 'Python Basic 4.ipynb', 'day 25.pdf', 'SQL For Data Science.pdf', 'SCREEENING.ipynb', '3. Pandas Data Manipulation.ipynb', 'day 19.pdf', 'Python Basic Assignment 18.ipynb', 'ML Engineering.pdf', 'SQL Commands Handwritten.pdf', 'Programming Assignment-08.ipynb', 'Assignment_21-checkpoint.ipynb', 'Advance_Assignment_01.ipynb', 'Natural_Language_Processing_with_Python.pdf', 'Python Basic Assignment - 9.ipynb', 'Python Basic Assignment 19-checkpoint.ipynb', 'Basic_Programming_Assignment_12.ipynb', 'Ineuron_Python_Advance_Assignment19.ipynb', 'Transfer Learning - Qiang Yang.pdf', 'Mathematics for Machine Learning.pdf', '12. Xgboost.ipynb', 'Ineuron_Python_Advanced_Programming14.ipynb', 'Python Basic Assignment - 11.ipynb', '4. Linear Models for Classification & Regression.ipynb', 'HR_Analytics_EDA.ipynb', 'Basic_Programming_Assignment_10.ipynb', '05.Practical Assignment_05.ipynb', '24.Programming Assignment_24.ipynb', 'DS Cheatsheet 1.0.pdf', 'day 27.pdf', 'Advance_Assignment_03.ipynb', 'day 9.pdf', '006.Assignment_6.ipynb', 'Python Programming Basic Assignment 1.ipynb', 'Matplotlib_Jupyter_Notebook.pdf', '013.Assignment_13.ipynb', 'Assignment_11.ipynb', 'Advance Programming Assignment 4.ipynb', '10. PCA Practical.ipynb', 'Ineuron_Python_Assignment08.ipynb', 'Dropout_Regularization.ipynb', '08.Practical Assignment_08.ipynb', '10. Clustering - K mean.ipynb', 'SQL document Part-2.pdf', '6. Decision Tree Coding.ipynb', 'Programming Assignment_8.ipynb', 'Ineuron_Python_Advance_Assignment24.ipynb', 'Assignment_4-checkpoint.ipynb', 'Statistics for Business and Economics.pdf', 'Associate Data Scientist at ZIGRAM .pdf', 'An Introduction to Statistical Learning(1).pdf', 'Python Advanced Programming 20.ipynb', 'Day 1.ipynb', 'Basic_Programming_Assignment_09.ipynb', 'Seaborn_python_cheatsheet.pdf', 'Data Science blogs.pdf', 'Amazon Simple Storage Service.pdf', 'Advance Programming Assignment 19.ipynb', 'Programming Assignment-13.ipynb', 'UltimateGuidetoDataScienceInterviews-2.pdf', '04.Practical Assignment_04.ipynb', 'Assignment - 03-checkpoint.ipynb', 'Assignment - 16.ipynb', 'Oracle9_SQL.pdf', 'Python Basic Programming 12.ipynb', 'NLP_Assignment_03-checkpoint.ipynb', 'Hadoop-The.Definitive.Guide_4.edition_a_Tom.White_April-2015-1.pdf', 'Python Basic Assignment 03.ipynb', 'Assignment_14-checkpoint.ipynb', 'ML_Assignment_01-checkpoint.ipynb', 'Python_Basics_Assignment_13.ipynb', 'Python Basic Assignme ...
# ---------------------------------------------------------------------------
# SameFileError                             Traceback (most recent call last)
# /var/folders/t_/0xqnxt590_q3q2xk8hccdjg00000gn/T/ipykernel_2888/665782234.py in <module>
#      19 source = '/Users/miteshwarke/Documents/iNeuron FSDS'
#      20 destination = '/Users/miteshwarke/Documents/iNeuron FSDS/test'
# ---> 21 search_and_copy(source, destination, extensions)
#
# /var/folders/t_/0xqnxt590_q3q2xk8hccdjg00000gn/T/ipykernel_2888/665782234.py in search_and_copy(source, destination, extensions)
#      13             if extension in extensions:
#      14                 targetFile = foldername+os.path.sep+fileName+extension
# ---> 15                 shutil.copy(targetFile, destination)
#      16         print(f'Files copied successfully from {source} to {destination}')
#      17
#
# ~/opt/anaconda3/lib/python3.9/shutil.py in copy(src, dst, follow_symlinks)
#     424     if os.path.isdir(dst):
#     425         dst = os.path.join(dst, os.path.basename(src))
# --> 426     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     427     copymode(src, dst, follow_symlinks=follow_symlinks)
#     428     return dst
#
# ~/opt/anaconda3/lib/python3.9/shutil.py in copyfile(src, dst, follow_symlinks)
#     242
#     243     if _samefile(src, dst):
# --> 244         raise SameFileError("{!r} and {!r} are the same file".format(src, dst))
#     245
#     246     file_size = 0
#
# SameFileError: '/Users/miteshwarke/Documents/iNeuron FSDS/test/Essiesltd.pdf' and '/Users/miteshwarke/Documents/iNeuron FSDS/test/Essiesltd.pdf' are the same file
